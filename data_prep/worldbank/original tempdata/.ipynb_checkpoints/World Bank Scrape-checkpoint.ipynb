# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import requests
import pandas as pd
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import Select
import os

# %%
cloud_path = '/Users/gamzebilsen/Downloads/chromedriver 2'
drive = webdriver.Chrome(cloud_path)
URL = "https://climateknowledgeportal.worldbank.org/download-data"
drive.get(URL)
# Out:
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/4163549645.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   drive = webdriver.Chrome(cloud_path)

# %%
passed = []
country_list = pd.read_csv(os.getcwd()+'/country_codes.csv')['Code'].to_list()
clim_list = ['tas','tasmin','tasmax','pr']
for country in country_list:
    try:
        for temp_type in clim_list:
            time.sleep(0.5)
            a = drive.find_element_by_xpath('/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[2]/div/select')
            a = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[2]/div/select"))
            a.select_by_value(temp_type)
            time.sleep(0.5)
            d = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[3]/div/select"))
            d.select_by_value('annual')
            e = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[4]/div/select"))
            e.select_by_value('country')
            b = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[5]/div/select"))
            b.select_by_value(country)
            time.sleep(0.5)
            e = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[10]/div/select"))
            e.select_by_value('historical')
            c = drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[14]/div[2]/button")
            c.click()
            time.sleep(0.5)
    except:
        passed.append(country)
# Out:
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:8: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   a = drive.find_element_by_xpath('/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[2]/div/select')
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   a = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[2]/div/select"))
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:12: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   d = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[3]/div/select"))
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   e = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[4]/div/select"))
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   b = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[5]/div/select"))
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   e = Select(drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[10]/div/select"))
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_43140/3966886213.py:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   c = drive.find_element_by_xpath("/html/body/div[1]/div[1]/div/section/div[2]/section/div/div/div/div/div/div/div[3]/form/div[14]/div[2]/button")

# %% [markdown]
# ### Country's together

# %%
# Getting rid of the countries that weren't pulled
country_list = pd.read_csv(os.getcwd()+'/country_codes.csv')#['Code'].to_list()
# matched_code = pd.DataFrame(list(set(country_list) - set(passed)))
# country_list.merge(matched_code, left_on='lkey', right_on='rkey')
# pulled_country = pd.read_csv(os.getcwd()+'/country_codes.csv').merge(matched_code, left_on='Code', right_on=0,how='inner')
# pulled_country = pulled_country[['Country_name','Code']]
country_list.index=country_list['Code']
country_list = country_list[['Country_name']]
country_dict = country_list.T.to_dict(orient='records')

# %%
prdf = pd.DataFrame()
tmax = pd.DataFrame()
tmin = pd.DataFrame()
tmean = pd.DataFrame()
from pathlib import Path
for file in os.listdir():
#     for k,v in country_dict[0].items():
    try:
        if file.startswith('pr'):
            x = pd.read_csv(file,skiprows=1).iloc[:,1]
            prdf = pd.concat([prdf,x],axis=1)
    except:
        prdf = pd.concat([prdf,pd.DataFrame(['empty'])])
    try:
        if file.startswith('tas_'):
            x = pd.read_csv(file,skiprows=1).iloc[:,1]
            tmean = pd.concat([tmean,x],axis=1)
    except:
        tmean = pd.concat([tmean,pd.DataFrame(['empty'])])
    try:
        if file.startswith('tasmax'):
            x = pd.read_csv(file,skiprows=1).iloc[:,1]
            tmax = pd.concat([tmax,x],axis=1)
    except:
        tmax = pd.concat([tmax,pd.DataFrame(['empty'])])
    try:
        if file.startswith('tasmin'):
            x = pd.read_csv(file,skiprows=1).iloc[:,1]
            tmin = pd.concat([tmin,x],axis=1)
    except:
        tmin = pd.concat([tmin,pd.DataFrame(['empty'])])

# %%
prdf['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
tmean['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
tmin['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
tmax['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
# Out:
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_45412/1608645339.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   prdf['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_45412/1608645339.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   tmean['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_45412/1608645339.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   tmin['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]
# /var/folders/2g/x52yhs_s6h96x64ydv7ck14m0000gn/T/ipykernel_45412/1608645339.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   tmax['Date'] = pd.read_csv('pr_timeseries_annual_cru_1901-2020_ISR.csv',skiprows=1).iloc[:,0]

# %%
prdf.to_csv('prdf.csv')
tmean.to_csv('tmean.csv')
tmin.to_csv('tmin.csv')
tmax.to_csv('tmax.csv')

# %%
country_dict
# Out:
# [{'AFG': 'Afghanistan',
#   'ALB': 'Albania',
#   'DZA': 'Algeria',
#   'ASM': 'American Samoa',
#   'AND': 'Andorra',
#   'AGO': 'Angola',
#   'AIA': 'Anguila',
#   'ATG': 'Antigua and Barbuda',
#   'ARG': 'Argentina',
#   'ARM': 'Armenia',
#   'ABW': 'Aruba',
#   'AUS': 'Australia',
#   'AUT': 'Austria',
#   'AZE': 'Azerbaijan',
#   'BHS': 'Bahamas, The',
#   'BHR': 'Bahrain',
#   'BGD': 'Bangladesh',
#   'BRB': 'Barbados',
#   'BLR': 'Belarus',
#   'BEL': 'Belgium',
#   'BLX': 'Belgium-Luxembourg',
#   'BLZ': 'Belize',
#   'BEN': 'Benin',
#   'BMU': 'Bermuda',
#   'BTN': 'Bhutan',
#   'BOL': 'Bolivia',
#   'BIH': 'Bosnia and Herzegovina',
#   'BWA': 'Botswana',
#   'BAT': 'Br. Antr. Terr',
#   'BRA': 'Brazil',
#   'IOT': 'British Indian Ocean Ter.',
#   'VGB': 'British Virgin Islands',
#   'BRN': 'Brunei',
#   'BGR': 'Bulgaria',
#   'BFA': 'Burkina Faso',
#   'BDI': 'Burundi',
#   'KHM': 'Cambodia',
#   'CMR': 'Cameroon',
#   'CAN': 'Canada',
#   'CPV': 'Cape Verde',
#   'CYM': 'Cayman Islands',
#   'CAF': 'Central African Republic',
#   'TCD': 'Chad',
#   'CHL': 'Chile',
#   'CHN': 'China',
#   'CXR': 'Christmas Island',
#   'CCK': 'Cocos (Keeling) Islands',
#   'COL': 'Colombia',
#   'COM': 'Comoros',
#   'ZAR': 'Congo, Dem. Rep.',
#   'COG': 'Congo, Rep.',
#   'COK': 'Cook Islands',
#   'CRI': 'Costa Rica',
#   'CIV': "Cote d'Ivoire",
#   'HRV': 'Croatia',
#   'CUB': 'Cuba',
#   'CYP': 'Cyprus',
#   'CZE': 'Czech Republic',
#   'CSK': 'Czechoslovakia',
#   'DNK': 'Denmark',
#   'DJI': 'Djibouti',
#   'DMA': 'Dominica',
#   'DOM': 'Dominican Republic',
#   'TMP': 'East Timor',
#   'ECU': 'Ecuador',
#   'EGY': 'Egypt, Arab Rep.',
#   'SLV': 'El Salvador',
#   'GNQ': 'Equatorial Guinea',
#   'ERI': 'Eritrea',
#   'EST': 'Estonia',
#   'ETH': 'Ethiopia (excludes Eritrea)',
#   'ETF': 'Ethiopia (includes Eritrea)',
#   'EUN': 'European Union',
#   'FRO': 'Faeroe Islands',
#   'FLK': 'Falkland Island',
#   'FJI': 'Fiji',
#   'FIN': 'Finland',
#   'PCZ': 'Fm Panama Cz',
#   'ZW1': 'Fm Rhod Nyas',
#   'TAN': 'Fm Tanganyik',
#   'VDR': 'Fm Vietnam Dr',
#   'SVR': 'Fm Vietnam Rp',
#   'ZPM': 'Fm Zanz-Pemb',
#   'ATF': 'Fr. So. Ant. Tr',
#   'FRA': 'France',
#   'FRE': 'Free Zones',
#   'GUF': 'French Guiana',
#   'PYF': 'French Polynesia',
#   'GAB': 'Gabon',
#   'GMB': 'Gambia, The',
#   'GAZ': 'Gaza Strip',
#   'GEO': 'Georgia',
#   'DDR': 'German Democratic Republic',
#   'DEU': 'Germany',
#   'GHA': 'Ghana',
#   'GIB': 'Gibraltar',
#   'GRC': 'Greece',
#   'GRL': 'Greenland',
#   'GRD': 'Grenada',
#   'GLP': 'Guadeloupe',
#   'GUM': 'Guam',
#   'GTM': 'Guatemala',
#   'GIN': 'Guinea',
#   'GNB': 'Guinea-Bissau',
#   'GUY': 'Guyana',
#   'HTI': 'Haiti',
#   'VAT': 'Holy See',
#   'HND': 'Honduras',
#   'HKG': 'Hong Kong, China',
#   'HUN': 'Hungary',
#   'ISL': 'Iceland',
#   'IND': 'India',
#   'IDN': 'Indonesia',
#   'IRN': 'Iran',
#   'IRQ': 'Iraq',
#   'IRL': 'Ireland',
#   'ISR': 'Israel',
#   'ITA': 'Italy',
#   'JAM': 'Jamaica',
#   'JPN': 'Japan',
#   'JTN': 'Jhonston Island',
#   'JOR': 'Jordan',
#   'KAZ': 'Kazakhstan',
#   'KEN': 'Kenya',
#   'KIR': 'Kiribati',
#   'PRK': 'Korea, Dem. Rep.',
#   'KOR': 'Korea, Rep.',
#   'KWT': 'Kuwait',
#   'KGZ': 'Kyrgyz Republic',
#   'LAO': 'Lao PDR',
#   'LVA': 'Latvia',
#   'LBN': 'Lebanon',
#   'LSO': 'Lesotho',
#   'LBR': 'Liberia',
#   'LBY': 'Libya',
#   'LIE': 'Liechtenstein',
#   'LTU': 'Lithuania',
#   'LUX': 'Luxembourg',
#   'MAC': 'Macao',
#   'MKD': 'Macedonia, FYR',
#   'MDG': 'Madagascar',
#   'MWI': 'Malawi',
#   'MYS': 'Malaysia',
#   'MDV': 'Maldives',
#   'MLI': 'Mali',
#   'MLT': 'Malta',
#   'MHL': 'Marshall Islands',
#   'MTQ': 'Martinique',
#   'MRT': 'Mauritania',
#   'MUS': 'Mauritius',
#   'MEX': 'Mexico',
#   'FSM': 'Micronesia, Fed. Sts.',
#   'MID': 'Midway Islands',
#   'MDA': 'Moldova',
#   'MCO': 'Monaco',
#   'MNG': 'Mongolia',
#   'MSR': 'Montserrat',
#   'MAR': 'Morocco',
#   'MOZ': 'Mozambique',
#   'MMR': 'Myanmar',
#   'NAM': 'Namibia',
#   'NRU': 'Nauru',
#   'NPL': 'Nepal',
#   'NLD': 'Netherlands',
#   'ANT': 'Netherlands Antilles',
#   'NZE': 'Neutral Zone',
#   'NCL': 'New Caledonia',
#   'NZL': 'New Zealand',
#   'NIC': 'Nicaragua',
#   'NER': 'Niger',
#   'NGA': 'Nigeria',
#   'NIU': 'Niue',
#   'NFK': 'Norfolk Island',
#   'MNP': 'Northern Mariana Islands',
#   'NOR': 'Norway',
#   'OMN': 'Oman',
#   'PCE': 'Pacific Islands',
#   'PAK': 'Pakistan',
#   'PLW': 'Palau',
#   'PAN': 'Panama',
#   'PNG': 'Papua New Guinea',
#   'PRY': 'Paraguay',
#   'PMY': 'Pen Malaysia',
#   'PER': 'Peru',
#   'PHL': 'Philippines',
#   'PCN': 'Pitcairn',
#   'POL': 'Poland',
#   'PRT': 'Portugal',
#   'PRI': 'Puerto Rico',
#   'QAT': 'Qatar',
#   'REU': 'Reunion',
#   'ROM': 'Romania',
#   'RUS': 'Russian Federation',
#   'RWA': 'Rwanda',
#   'RYU': 'Ryukyu Is',
#   'SBH': 'Sabah',
#   'SHN': 'Saint Helena',
#   'KN1': 'Saint Kitts-Nevis-Anguilla-Aru',
#   'SPM': 'Saint Pierre and Miquelon',
#   'WSM': 'Samoa',
#   'SMR': 'San Marino',
#   'STP': 'Sao Tome and Principe',
#   'SWK': 'Sarawak',
#   'SAU': 'Saudi Arabia',
#   'SEN': 'Senegal',
#   'SYC': 'Seychelles',
#   'SLE': 'Sierra Leone',
#   'SIK': 'SIKKIM',
#   'SGP': 'Singapore',
#   'SVK': 'Slovak Republic',
#   'SVN': 'Slovenia',
#   'SLB': 'Solomon Islands',
#   'SOM': 'Somalia',
#   'ZAF': 'South Africa',
#   'SVU': 'Soviet Union',
#   'ESP': 'Spain',
#   'SPE': 'Special Categories',
#   'LKA': 'Sri Lanka',
#   'KNA': 'St. Kitts and Nevis',
#   'LCA': 'St. Lucia',
#   'VCT': 'St. Vincent and the Grenadines',
#   'SDN': 'Sudan',
#   'SUR': 'Suriname',
#   'SJM': 'Svalbard and Jan Mayen Is',
#   'SWZ': 'Swaziland',
#   'SWE': 'Sweden',
#   'CHE': 'Switzerland',
#   'SYR': 'Syrian Arab Republic',
#   'TWN': 'Taiwan',
#   'TJK': 'Tajikistan',
#   'TZA': 'Tanzania',
#   'THA': 'Thailand',
#   'TGO': 'Togo',
#   'TKL': 'Tokelau',
#   'TON': 'Tonga',
#   'TTO': 'Trinidad and Tobago',
#   'TUN': 'Tunisia',
#   'TUR': 'Turkey',
#   'TKM': 'Turkmenistan',
#   'TCA': 'Turks and Caicos Isl.',
#   'TUV': 'Tuvalu',
#   'UGA': 'Uganda',
#   'UKR': 'Ukraine',
#   'ARE': 'United Arab Emirates',
#   'GBR': 'United Kingdom',
#   'USA': 'United States',
#   'UNS': 'Unspecified',
#   'URY': 'Uruguay',
#   'USP': 'Us Msc.Pac.I',
#   'UZB': 'Uzbekistan',
#   'VUT': 'Vanuatu',
#   'VEN': 'Venezuela',
#   'VNM': 'Vietnam',
#   'VIR': 'Virgin Islands (U.S.)',
#   'WAK': 'Wake Island',
#   'WLF': 'Wallis and Futura Isl.',
#   'ESH': 'Western Sahara',
#   'WLD': 'World',
#   'YDR': 'Yemen Democratic',
#   'YEM': 'Yemen, Rep.',
#   'SER': 'Yugoslavia',
#   'YUG': 'Yugoslavia, FR (Serbia/Montene',
#   'ZMB': 'Zambia',
#   'ZWE': 'Zimbabwe'}]

# %%
os.getcwd()
# Out:
# '/Users/gamzebilsen/Documents/GitHub/Group_J_Climate_Economics/data_prep/worldbank/climate'
